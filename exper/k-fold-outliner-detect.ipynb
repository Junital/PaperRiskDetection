# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold

# %%
skf = StratifiedKFold(n_splits=5)
df = pd.read_csv("../data/repa_data_20231109.csv")
df.columns
# Out:
# Index(['is_retracted', 'published_time', 'total_comment', 'author_active',
#        'comment_len', 'reword', 'squ_published_time', 'squ_total_comment',
#        'squ_author_active', 'squ_comment_len', 'squ_reword',
#        'sqrt_published_time', 'sqrt_total_comment', 'sqrt_author_active',
#        'sqrt_comment_len', 'sqrt_reword'],
#       dtype='object')

# %%
Y = df["is_retracted"]
X = df.drop("is_retracted", axis=1)

# %%
skf.get_n_splits(X, Y)

for i, (train_index, test_index) in enumerate(skf.split(X, Y)):
    print(f"Fold {i}:")
    print(f"  Train: index={train_index}")
    print(f"  Test:  index={test_index}")
# Out:
# Fold 0:
#   Train: index=[  473   474   475 ... 25643 25644 25645]
#   Test:  index=[   0    1    2 ... 7015 7016 7017]
# Fold 1:
#   Train: index=[    0     1     2 ... 25643 25644 25645]
#   Test:  index=[  473   474   475 ... 11672 11673 11674]
# Fold 2:
#   Train: index=[    0     1     2 ... 25643 25644 25645]
#   Test:  index=[  945   946   947 ... 16329 16330 16331]
# Fold 3:
#   Train: index=[    0     1     2 ... 25643 25644 25645]
#   Test:  index=[ 1417  1418  1419 ... 20986 20987 20988]
# Fold 4:
#   Train: index=[    0     1     2 ... 20986 20987 20988]
#   Test:  index=[ 1889  1890  1891 ... 25643 25644 25645]

# %%
# Out:
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-34.516242424579211 > -34.830007180566469). You may want to try with a higher value of support_fraction (current value: 0.502).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-34.510044728328474 > -35.025107150699831). You may want to try with a higher value of support_fraction (current value: 0.502).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-34.361582904879953 > -34.864094921926373). You may want to try with a higher value of support_fraction (current value: 0.502).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-91.814795595763371 > -93.487206337438820). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-46.490386233548818 > -68.127573531843680). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-72.616586049643175 > -72.977725705842929). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-68.217584699351022 > -68.866273462758159). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-70.770359469101535 > -100.428518986630166). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-99.205520709925750 > -101.721684133247422). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-45.723419782171085 > -46.049277759289609). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-45.601014357407401 > -45.670282484692386). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-67.741769739561036 > -69.193586516487670). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-67.934528111659645 > -68.090382412241851). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-70.755587931678718 > -71.079437940665329). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-44.869191664875672 > -45.586705528531795). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-45.297321674796336 > -45.438228081365899). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-45.272883453603328 > -45.385086479042002). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-69.954725336158447 > -72.540003651942428). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-44.945359380734047 > -45.258905691251151). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-45.860024005076454 > -46.355544682436289). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-45.386916251591103 > -45.604385092695836). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-67.737228712557595 > -67.982220910931531). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-68.069716072837622 > -70.263600267546451). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-89.714626854851872 > -91.950426611900511). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-73.363487781545601 > -73.412662762086427). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-93.905160696097212 > -94.251650243425942). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-66.149216854052497 > -70.231500261031186). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-45.591652211417774 > -45.904668676356906). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-70.170390312274492 > -71.163294303749595). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-67.933165312610015 > -68.699527680200134). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-67.934528111659645 > -68.015670774771124). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-45.414387062128583 > -45.649816308899474). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-68.414237691935284 > -69.016195294690547). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-69.088114456030127 > -69.379149799650776). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# f:\Anaconda3\envs\repallm\lib\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (