# %%
import seaborn as sns
import pandas as pd

df = pd.read_excel("../data/repa_data_20231007.xlsx")
df.head()
# Out:
#                        pubpeer_id  \
# 0  002C71700B7E707DE2FE75C198BAC7
# 1  003FFE17AF3EFB7D5486389615AD3E
# 2  00442961D0994CC6C186D8C1558B09
# 3  005D80C447F09C2008B6397015BE9F
# 4  005DF8CACBC0BED0BE5FE67C32FC97
#
#                                                title comments_total  \
# 0  Antileukemic effect of zerumbone-loaded nanost...              2
# 1  Homeopathy combat against coronavirus disease ...             12
# 2  Long noncoding RNA SNHG22 increases ZEB1 expre...              2
# 3  Litchi Seed Aqueous Extracts play a role in su...              2
# 4  Long non-coding RNA MIAT promotes non-small ce...              2
#
#                                             journals published_time  \
# 0              International Journal of Nanomedicine           2015
# 1  Zeitschrift fur Gesundheitswissenschaften = Jo...           2020
# 2                      Cell cycle (Georgetown, Tex.)           2020
# 3                                         Cell Cycle           2020
# ...

# %%
sns.boxplot(data=df, x="published_time", y="is_retracted")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\D\xiaochengxu\python\dev\repallm\draw\variable_box_plot.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/D/xiaochengxu/python/dev/repallm/draw/variable_box_plot.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> sns.boxplot(data=df, x="published_time", y="is_retracted")
#
# File f:\Anaconda3\envs\repallm\lib\site-packages\seaborn\categorical.py:1604, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1601 if p.var_types.get(p.orient) == "categorical" or not native_scale:
#    1602     p.scale_categorical(p.orient, order=order, formatter=formatter)
# -> 1604 p._attach(ax, log_scale=log_scale)
#    1606 # Deprecations to remove in v0.14.0.
# ...
